# %% [markdown]
# # Preprocessing and Exploring
# This notebook cleans the data of the bills, attaches it to the authors data and its parties. After that it explores the data.

# %%
import pandas as pd
import numpy as np
import re
import ast
# !pip install unidecode
from unidecode import unidecode
# !pip install thefuzz
from thefuzz import fuzz
from thefuzz import process
import matplotlib.pyplot as plt

# %%
raw_path = './Raw/'
bills_path = raw_path + 'Bills_txt'

# %% [markdown]
# ## Uploading the data

# %%
bills_txt_info = pd.read_csv(raw_path + 'Bills 2022 - 2026.csv')
bills_txt_info.head(10)  
# Title is the name of the text file, url is the source, 
# the type of bill if it is a change of the constitution (Acto legislativo) or an ordinary law (Proyecto de ley)
# The year is the period of sessions in which it was introduced and period is just an indicator of the 4 year period of Congress
# Out:
#                                                title  \
# 0                    277-24 SEDE PRINCIPAL DE LA CDA
# 1                      276-24 RESTITUCIÓN DE TIERRAS
# 2                   275-24 PERSONAS CON DISCAPACIDAD
# 3                PL 274-24 HONORES MUNICIPIO GUATAPÉ
# 4                          PL 273-24 CHORROS BLANCOS
# 5  PL 272-24 CÓDIGO NACIONAL Y CONVIVENCIA CIUDADANA
# 6                       PL 271-24 AMPARO ALIMENTARIO
# 7   PL 270-24 CONVIVENCIA Y SEGURIDAD EN TERRITORIOS
# 8                                  PL 269-24 POPAYÁN
# 9             PL 267-24 PROTECCIÓN ANIMAL EN TURISMO
#
#                                                  url        type_bill  \
# 0  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 1  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 2  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 3  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 4  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 5  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 6  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 7  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 8  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 9  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
#
#         year       period
# 0  2024-2025  2022 - 2026
# 1  2024-2025  2022 - 2026
# 2  2024-2025  2022 - 2026
# 3  2024-2025  2022 - 2026
# 4  2024-2025  2022 - 2026
# 5  2024-2025  2022 - 2026
# 6  2024-2025  2022 - 2026
# 7  2024-2025  2022 - 2026
# 8  2024-2025  2022 - 2026
# 9  2024-2025  2022 - 2026

# %%
def get_bill_number(bill_title, leg_year, bill_type):
    numbers = list(map(str, re.findall(r'\d+', bill_title)))[:1]  # Should be ['ddd']
    dd_yr = leg_year[2:4]
    bt = "PL"  # Indicator for law
    if "Acto" in bill_type:  
        bt = "AL"  # Indicator for change to the Constitution
    if len(numbers) > 0:
        zero_mis = 3 - len(numbers[0])
        numbers[0] = '0' * zero_mis + numbers[0]
        numbers.append(dd_yr)
        if len(numbers[0]) == 3:  # Assert
            return bt + '-'.join(numbers)
    
    return ''  # Missing or incorrect number
    
bills_txt_info['number'] = bills_txt_info.apply(lambda row: get_bill_number(row['title'], row['year'], row['type_bill']), axis=1)
bills_txt_info['number'].value_counts()
# Out:
# number
# PL228-22    2
# PL277-24    1
# PL236-22    1
# PL246-22    1
# PL245-22    1
#            ..
# PL214-23    1
# PL213-23    1
# PL212-23    1
# PL211-23    1
# AL001-22    1
# Name: count, Length: 840, dtype: int64

# %%
bills_txt_info[bills_txt_info['number']=='PL228-22']
# Out:
#                                             title  \
# 570  PL-228 Despolarizacion y pluralismo politico
# 571                                    PL-228 PAE
#
#                                                    url        type_bill  \
# 570  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 571  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
#
#           year       period    number
# 570  2022-2023  2022 - 2026  PL228-22
# 571  2022-2023  2022 - 2026  PL228-22

# %%
# There is a mistake in the numbers of the PDF
# Despolarizacion y pluralismo politico should be 229-22
bills_txt_info.loc[bills_txt_info['title']=='PL-228 Despolarizacion y pluralismo politico', 'number'] = 'PL229-22'

# %%
# Using the bill information from the House of Representative because the info from the Senate does not have bill type
bills_house = pd.read_csv(raw_path + 'Cámara 2022 - 2026.csv')
bills_house
# Out:
#      No Cámara  No Senado                                 Nombre proyecto  \
# 0    448/2024C  062/2023S         VIOLENCIA VICARIA - LEY GABRIEL ESTEBAN
# 1    447/2024C        NaN  INFRAESTRUCTURA DE DATOS DEL ESTADO COLOMBIANO
# 2    446/2024C        NaN                              CALYPSO PATRIMONIO
# 3    445/2024C  075/2022S                  CONVENIO RESPONSABILIDAD CIVIL
# 4    444/2024C  021/2024S                             FUERZA AEROESPACIAL
# ..         ...        ...                                             ...
# 864  003/2022C        NaN                       DERECHOS DE LA NATURALEZA
# 865  002/2022C  033/2022S                                        CANNABIS
# 866  001/2022C        NaN                            INDUSTRIA Y COMERCIO
# 867  479/2022C        NaN                          INSOLVENCIA EMPRESARIA
# 868  478/2022C        NaN                            INTERVENCION ESTATAL
#
#           Tipo de ley                                            Autores  \
# 0       Ley Ordinaria  ['Ruth Amelia Caycedo Rosero', ' Delcy Esperan...
# 1       Ley Ordinaria  ['Ministro de Tecnologías de la Información y ...
# 2       Ley Ordinaria  ['Elizabeth Jay-Pang Díaz', ' Gersel Luis Pére...
# 3       Ley Ordinaria  ['Ministro de Relaciones Exteriores - Martha L...
# 4    Acto Legislativo  ['Ministro de Defensa Nacional - Ivan Velasque...
# ..                ...                                                ...
# 864  Acto Legislativo  ['Juan Carlos Lozada Vargas', ' Julián Peinado...
# 865  Acto Legislativo  ['Juan Carlos Lozada Vargas', ' Julián David L...
# 866     Ley Ordinaria  ['Juan Diego Muñoz Cabrera', ' Julián Peinado ...
# 867     Ley Ordinaria                     ['H.R.Santiago Morales Saenz']
# 868     Ley Ordinaria                     ['H.R.Santiago Morales Saenz']
#
#                   Estado                                          Comisión  \
# 0    Trámite en Comisión        Comisión Primera Constitucional Permanente
# 1    Trámite en Comisión  Comisión Sexta o de Transportes y Comunicaciones
# 2    Trámite en Comisión  Comisión Sexta o de Transportes y Comunicaciones
# 3    Trámite en Comisión  Comisión Segunda o de Relaciones Internacionales
# 4    Trámite en Comisión        Comisión Primera Constitucional Permanente
# ..                   ...                                               ...
# 864            Archivado        Comisión Primera Constitucional Permanente
# 865            Archivado        Comisión Primera Constitucional Permanente
# 866            Archivado  Comisión Tercera o de Hacienda y Crédito Público
# 867            Archivado        Comisión Primera Constitucional Permanente
# 868            Archivado        Comisión Primera Constitucional Permanente
#
#      Origen  Legislatura                                             Título  \
# 0    Senado  2023 - 2024  Por medio del cual se dictan medidas para reco...
# 1    Cámara  2023 - 2024  Por medio de la cual se dictan disposiciones p...
# 2    Cámara  2023 - 2024  Por medio del cual se declara patrimonio cultu...
# 3    Senado  2023 - 2024  POR MEDIO DEL CUAL SE APRUEBA EL CONVENIO INTE...
# 4    Senado  2023 - 2024  Por el cual se modifica el inciso 1 del artícu...
# ..      ...          ...                                                ...
# 864  Cámara  2022 - 2023  Por el cual se modifican los artículos 79 y 95...
# 865  Cámara  2022 - 2023  Por medio del cual se modifica el artículo 49 ...
# 866  Cámara  2022 - 2023  Por medio del cual el impuesto de industria y ...
# 867  Cámara  2021 - 2022  Por medio del cual se garantiza el derecho al ...
# 868  Cámara  2021 - 2022  Por medio del cual se modifica el Decreto Legi...
#
#                                                  Autor  \
# 0    ['Nadya Georgette Blel Scaf', 'Germán Alcides ...
# 1    ['Julio Elias Vidal', 'Alex Xavier Flórez Hern...
# 2    ['Elizabeth Jay Pang Díaz', 'Gersel Luis Pérez...
# 3    ['Ministro de Relaciones Exteriores Martha Luc...
# 4    ['Carlos Alberto Benavides Mora', 'Nicolás Alb...
# ..                                                 ...
# 864  ['Alejandro Alberto Vega Pérez', 'Nicolás Albe...
# 865  ['Alejandro Alberto Vega Pérez', 'Alejandro Ca...
# 866  ['Ana carolina Espitia Jerez', 'Juan Diego Muñ...
# 867                         ['Santiago Morales Saenz']
# 868                         ['Santiago Morales Saenz']
#
#                         No de proyecto                  Fecha de radicación  \
# 0    Cámara 448 2024C Senado 062 2023S  Cámara 2024 05 23 Senado 2023 08 02
# 1              Cámara 447 2024C Senado             Cámara 2024 05 22 Senado
# 2              Cámara 446 2024C Senado             Cámara 2024 05 21 Senado
# 3    Cámara 445 2024C Senado 075 2022S  Cámara 2024 05 21 Senado 2022 07 29
# 4    Cámara 444 2024C Senado 021 2024S  Cámara 2024 05 21 Senado 2024 04 02
# ..                                 ...                                  ...
# 864            Cámara 003 2022C Senado             Cámara 2022 07 21 Senado
# 865  Cámara 002 2022C Senado 033 2022S             Cámara 2022 07 21 Senado
# 866            Cámara 001 2022C Senado             Cámara 2022 07 21 Senado
# 867            Cámara 479 2022C Senado             Cámara 2022 07 18 Senado
# 868            Cámara 478 2022C Senado             Cámara 2022 07 18 Senado
#
#                  Tipo             Contenido  \
# 0       Ley Ordinaria                   NaN
# 1       Ley Ordinaria                   NaN
# 2       Ley Ordinaria                   NaN
# 3       Ley Ordinaria                   NaN
# 4    Acto Legislativo                   NaN
# ..                ...                   ...
# 864  Acto Legislativo  Gaceta N 855 de 2022
# 865  Acto Legislativo     Gaceta N 855 2022
# 866     Ley Ordinaria  Gaceta N 857 de 2022
# 867     Ley Ordinaria  Gaceta N 847 de 2022
# 868     Ley Ordinaria  Gaceta N 847 de 2022
#
#                                     Objeto de proyecto  \
# 0    La presente ley tiene por objeto garantizar un...
# 1    La presente ley tiene por objeto establecer la...
# 2    La presente ley tiene declara patrimonio cultu...
# 3    Observaciones Primer debate cámara PONENTES Co...
# 4    Observaciones Primer debate cámara Primera PON...
# ..                                                 ...
# 864  La iniciativa de Acto Legislativo tiene como o...
# 865  El presente Proyecto de Acto Legislativo tiene...
# 866  Este proyecto de ley pretende declarar la comp...
# 867  Modificar la Ley 1116 de 2006 y la Ley 1564 de...
# 868  La presente Ley tiene por objeto reformar el D...
#
#                                          Observaciones  \
# 0                                                  NaN
# 1    Primer debate cámara PONENTES Coordinador es H...
# 2                                                  NaN
# 3    Primer debate cámara PONENTES Coordinador es H...
# 4    Primer debate cámara Primera PONENTES Coordina...
# ..                                                 ...
# 864  ARCHIVADO ART 224 y 225 LEY 5ta DE 1992 Primer...
# 865  Diario Oficial 1ra vuelta No 52 275 ARCHIVADO ...
# 866  ART 184 Ley 5ta 1992 EL 09 11 22 Primer debate...
# 867                       ARCHIVADO Art 190 ley 5ta 92
# 868                       ARCHIVADO Art 190 ley 5ta 92
#
#     Fecha radicación Cámara Fecha radicación Senado  \
# 0                2024 05 23              2023 08 02
# 1                2024 05 22                     NaN
# 2                2024 05 21                     NaN
# 3                2024 05 21              2022 07 29
# 4                2024 05 21              2024 04 02
# ..                      ...                     ...
# 864              2022 07 21                     NaN
# 865              2022 07 21                     NaN
# 866              2022 07 21                     NaN
# 867              2022 07 18                     NaN
# 868              2022 07 18                     NaN
#
#                                                    url
# 0    https://www.camara.gov.co/violencia-vicaria-le...
# 1    https://www.camara.gov.co/infraestructura-de-d...
# 2         https://www.camara.gov.co/calypso-patrimonio
# 3    https://www.camara.gov.co/convenio-responsabil...
# 4        https://www.camara.gov.co/fuerza-aeroespacial
# ..                                                 ...
# 864  https://www.camara.gov.co/derechos-de-la-natur...
# 865               https://www.camara.gov.co/cannabis-1
# 866     https://www.camara.gov.co/industria-y-comercio
# 867   https://www.camara.gov.co/insolvencia-empresaria
# 868     https://www.camara.gov.co/intervencion-estatal
#
# [869 rows x 20 columns]

# %%
bills_senate = pd.read_csv(raw_path + 'Senado 2022 - 2026.csv')
bills_senate
# Out:
#        Fecha Radicacion                             No Senado No Camara  \
# 0         02 Julio 2023                                345/23    148/22
# 1     22 Noviembre 2022                                344/23    290/22
# 2    26 Septiembre 2022                                343/23    209/22
# 3        10 Agosto 2022                                342/23    128/22
# 4       20 Octubre 2022                                341/23    244/22
# ..                  ...                                   ...       ...
# 939       20 Julio 2024                                005/24       NaN
# 940       20 Julio 2024  004/24 ACUMULADO AL PL 022/24 SENADO       NaN
# 941       20 Julio 2024                                003/24       NaN
# 942       20 Julio 2024                                002/24       NaN
# 943       20 Julio 2024                                001/24       NaN
#
#                                                 Estado  \
# 0                   LEY   2414 DEL 8 DE AGOSTO DE 2024
# 1               LEY   2427 DEL 9 DE SEPTIEMBRE DE 2024
# 2                   LEY   2389 DEL 26 DE JULIO DE 2024
# 3    ARCHIVADO   Art 190 Ley 5 de 1992 (No se discu...
# 4                 LEY   2408 DEL 05 DE AGOSTYO DE 2024
# ..                                                 ...
# 939  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
# 940  PENDIENTE RENDIR PONENCIA PARA PRIMER DEBATE E...
# 941  PENDIENTE DISCUTIR PONENCIA PARA SEGUNDO DEBAT...
# 942  PENDIENTE RENDIR PONENCIA PARA PRIMER DEBATE E...
# 943  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
#
#                                                 Titulo  \
# 0    POR LA CUAL SE ADICIONAN EL NUMERAL 4TO DEL AR...
# 1    POR MEDIO DEL CUAL SE ESTABLECE LA CÁTEDRA PAR...
# 2    POR MEDIO DEL CUAL SE ESTABLECE LA CANASTA BÁS...
# 3    POR MEDIO DE LA CUAL SE REGULAN LOS PRODUCTOS ...
# 4    POR MEDIO DE LA CUAL SE FACILITA EL INGRESO, P...
# ..                                                 ...
# 939  POR MEDIO DE LA CUAL SE FOMENTAN PRÁCTICAS REC...
# 940  POR EL CUAL SE REGULAN LAS CONDICIONES DE BIEN...
# 941  POR MEDIO DE LA CUAL SE PROHÍBE EL USO DEL GLI...
# 942  POR MEDIO DE LA CUAL SE MODIFICA Y ADICIONA A ...
# 943  POR MEDIO DE LA CUAL SE DICTAN LOS LINEAMIENTO...
#
#                                                Autores Comision   Cuatrienio  \
# 0    ['JUAN PABLO GALLO MAYA', 'PIEDAD CORREAL RUBI...    SEXTA  2022 - 2026
# 1    ['ANA CAROLINA ESPITIA JEREZ', 'EDWING FABIÁN ...    SEXTA  2022 - 2026
# 2    ['ANA CAROLINA ESPITIA JEREZ', 'ANGÉLICA LISBE...    SEXTA  2022 - 2026
# 3                               ['MILENE JARAVA DÍAZ']  SEPTIMA  2022 - 2026
# 4    ['INTI RAÚL ASPRILLA REYES', 'MARÍA JOSÉ PIZAR...  SEGUNDA  2022 - 2026
# ..                                                 ...      ...          ...
# 939  ['ESMERALDA HERNÁNDEZ SILVA', 'NICOLÁS ALBEIRO...  SEPTIMA  2022 - 2026
# 940  ['Senadores Nicolás Albeiro Echeverri Alvarán ...   QUINTA  2022 - 2026
# 941  ['ESMERALDA HERNÁNDEZ SILVA', 'RICHARD HUMBERT...   QUINTA  2022 - 2026
# 942  ['LORENA RIOS CUELLAR', 'JOSUE ALIRIO BARRERA ...  PRIMERA  2022 - 2026
# 943  ['LORENA RIOS CUELLAR', 'SOLEDAD TAMAYO TAMAYO...  SEPTIMA  2022 - 2026
#
#      Legislatura                                                url
# 0    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 1    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 2    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 3    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 4    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# ..           ...                                                ...
# 939  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 940  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 941  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 942  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 943  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
#
# [944 rows x 10 columns]

# %%
bills_senate['Tipo de ley'] = 'PL'
bills_senate['number'] = bills_senate.apply(lambda row: get_bill_number(row['No Senado'], row['Legislatura'], row['Tipo de ley']), axis=1)
bills_senate['number'].value_counts(dropna=False)
# Out:
# number
# PL345-22    1
# PL015-23    1
# PL027-23    1
# PL026-23    1
# PL025-23    1
#            ..
# PL027-22    1
# PL026-22    1
# PL025-22    1
# PL024-22    1
# PL001-24    1
# Name: count, Length: 944, dtype: int64

# %%
bills_merge = bills_senate.merge(bills_txt_info, on=['number'], how='left')
bills_merge
# Out:
#        Fecha Radicacion                             No Senado No Camara  \
# 0         02 Julio 2023                                345/23    148/22
# 1     22 Noviembre 2022                                344/23    290/22
# 2    26 Septiembre 2022                                343/23    209/22
# 3        10 Agosto 2022                                342/23    128/22
# 4       20 Octubre 2022                                341/23    244/22
# ..                  ...                                   ...       ...
# 939       20 Julio 2024                                005/24       NaN
# 940       20 Julio 2024  004/24 ACUMULADO AL PL 022/24 SENADO       NaN
# 941       20 Julio 2024                                003/24       NaN
# 942       20 Julio 2024                                002/24       NaN
# 943       20 Julio 2024                                001/24       NaN
#
#                                                 Estado  \
# 0                   LEY   2414 DEL 8 DE AGOSTO DE 2024
# 1               LEY   2427 DEL 9 DE SEPTIEMBRE DE 2024
# 2                   LEY   2389 DEL 26 DE JULIO DE 2024
# 3    ARCHIVADO   Art 190 Ley 5 de 1992 (No se discu...
# 4                 LEY   2408 DEL 05 DE AGOSTYO DE 2024
# ..                                                 ...
# 939  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
# 940  PENDIENTE RENDIR PONENCIA PARA PRIMER DEBATE E...
# 941  PENDIENTE DISCUTIR PONENCIA PARA SEGUNDO DEBAT...
# 942  PENDIENTE RENDIR PONENCIA PARA PRIMER DEBATE E...
# 943  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
#
#                                                 Titulo  \
# 0    POR LA CUAL SE ADICIONAN EL NUMERAL 4TO DEL AR...
# 1    POR MEDIO DEL CUAL SE ESTABLECE LA CÁTEDRA PAR...
# 2    POR MEDIO DEL CUAL SE ESTABLECE LA CANASTA BÁS...
# 3    POR MEDIO DE LA CUAL SE REGULAN LOS PRODUCTOS ...
# 4    POR MEDIO DE LA CUAL SE FACILITA EL INGRESO, P...
# ..                                                 ...
# 939  POR MEDIO DE LA CUAL SE FOMENTAN PRÁCTICAS REC...
# 940  POR EL CUAL SE REGULAN LAS CONDICIONES DE BIEN...
# 941  POR MEDIO DE LA CUAL SE PROHÍBE EL USO DEL GLI...
# 942  POR MEDIO DE LA CUAL SE MODIFICA Y ADICIONA A ...
# 943  POR MEDIO DE LA CUAL SE DICTAN LOS LINEAMIENTO...
#
#                                                Autores Comision   Cuatrienio  \
# 0    ['JUAN PABLO GALLO MAYA', 'PIEDAD CORREAL RUBI...    SEXTA  2022 - 2026
# 1    ['ANA CAROLINA ESPITIA JEREZ', 'EDWING FABIÁN ...    SEXTA  2022 - 2026
# 2    ['ANA CAROLINA ESPITIA JEREZ', 'ANGÉLICA LISBE...    SEXTA  2022 - 2026
# 3                               ['MILENE JARAVA DÍAZ']  SEPTIMA  2022 - 2026
# 4    ['INTI RAÚL ASPRILLA REYES', 'MARÍA JOSÉ PIZAR...  SEGUNDA  2022 - 2026
# ..                                                 ...      ...          ...
# 939  ['ESMERALDA HERNÁNDEZ SILVA', 'NICOLÁS ALBEIRO...  SEPTIMA  2022 - 2026
# 940  ['Senadores Nicolás Albeiro Echeverri Alvarán ...   QUINTA  2022 - 2026
# 941  ['ESMERALDA HERNÁNDEZ SILVA', 'RICHARD HUMBERT...   QUINTA  2022 - 2026
# 942  ['LORENA RIOS CUELLAR', 'JOSUE ALIRIO BARRERA ...  PRIMERA  2022 - 2026
# 943  ['LORENA RIOS CUELLAR', 'SOLEDAD TAMAYO TAMAYO...  SEPTIMA  2022 - 2026
#
#      Legislatura                                              url_x  \
# 0    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 1    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 2    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 3    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 4    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# ..           ...                                                ...
# 939  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 940  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 941  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 942  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 943  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
#
#     Tipo de ley    number                                  title  \
# 0            PL  PL345-22                                    NaN
# 1            PL  PL344-22                                    NaN
# 2            PL  PL343-22                                    NaN
# 3            PL  PL342-22                                    NaN
# 4            PL  PL341-22                                    NaN
# ..          ...       ...                                    ...
# 939          PL  PL005-24          PL 005-24 JUEGOS PIROTECNICOS
# 940          PL  PL004-24  PL 004-24 BIENESTAR ANIMAL Descargar
# 941          PL  PL003-24                    PL 003-24 GLIFOSATO
# 942          PL  PL002-24    PL 002-24 VICTIMAS SECTOR RELIGIOSO
# 943          PL  PL001-24    PL 001-24 CON LOS NIÑOS NO TE METAS
#
#                                                  url_y        type_bill  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 939  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 940  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 941  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 942  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
# 943  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
#
#           year       period
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# ..         ...          ...
# 939  2024-2025  2022 - 2026
# 940  2024-2025  2022 - 2026
# 941  2024-2025  2022 - 2026
# 942  2024-2025  2022 - 2026
# 943  2024-2025  2022 - 2026
#
# [944 rows x 17 columns]

# %%
bills_merge[bills_merge['number']=='PL228-22']
# Out:
#     Fecha Radicacion No Senado No Camara                             Estado  \
# 117  25 Octubre 2022    228/22       NaN  ARCHIVADO   Art 190 ley 5 de 1992
#
#                                                 Titulo  \
# 117  “POR EL CUAL SE FORTALECE EL PROGRAMA DE ALIME...
#
#                                                Autores Comision   Cuatrienio  \
# 117  ['Honorable  Senadores:ARTURO CHAR CHALJUB', '...    SEXTA  2022 - 2026
#
#      Legislatura                                              url_x  \
# 117  2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
#
#     Tipo de ley    number       title  \
# 117          PL  PL228-22  PL-228 PAE
#
#                                                  url_y        type_bill  \
# 117  https://leyes.senado.gov.co/proyectos/index.ph...  Proyecto de ley
#
#           year       period
# 117  2022-2023  2022 - 2026

# %%
bills_mis = bills_merge[bills_merge['title'].isna()]
bills_mis.loc[:, 'number'] = ''
bills_mis.loc[:, 'Tipo de ley'] = 'Acto'
bills_mis.loc[:, 'number'] = bills_mis.apply(lambda row: get_bill_number(row['No Senado'], row['Legislatura'], row['Tipo de ley']), axis=1)# The unmatched must be AL
bills_mis = bills_mis.loc[:,['number', 'No Senado','No Camara','Titulo','Autores','Fecha Radicacion',
                             'Comision','Estado']].copy()
bills_mis
# Out:
#        number No Senado                                          No Camara  \
# 0    AL345-22    345/23                                             148/22
# 1    AL344-22    344/23                                             290/22
# 2    AL343-22    343/23                                             209/22
# 3    AL342-22    342/23                                             128/22
# 4    AL341-22    341/23                                             244/22
# ..        ...       ...                                                ...
# 899  AL045-24    045/24                                             066/23
# 915  AL029-24    029/24  014/23 Acum 80/23 - 143/23 - 261/23 - 268/23 -...
# 916  AL028-24    028/24                                             213/23
# 917  AL027-24    027/24                                             377/24
# 918  AL026-24    026/24                                 007/23 Acum 044/23
#
#                                                 Titulo  \
# 0    POR LA CUAL SE ADICIONAN EL NUMERAL 4TO DEL AR...
# 1    POR MEDIO DEL CUAL SE ESTABLECE LA CÁTEDRA PAR...
# 2    POR MEDIO DEL CUAL SE ESTABLECE LA CANASTA BÁS...
# 3    POR MEDIO DE LA CUAL SE REGULAN LOS PRODUCTOS ...
# 4    POR MEDIO DE LA CUAL SE FACILITA EL INGRESO, P...
# ..                                                 ...
# 899  POR MEDIO DEL CUAL SE ESTABLECEN LOS OBJETIVOS...
# 915  POR MEDIO DEL CUAL SE MODIFICA LA LEY 1616 DE ...
# 916  POR MEDIO DE LA CUAL SE REDUCE EL IVA A LOS AC...
# 917  POR MEDIO DE LA CUAL SE MODIFICA LA LEY 2226 D...
# 918  POR MEDIO DEL CUAL SE REALIZA EL RECONOCIMIENT...
#
#                                                Autores    Fecha Radicacion  \
# 0    ['JUAN PABLO GALLO MAYA', 'PIEDAD CORREAL RUBI...       02 Julio 2023
# 1    ['ANA CAROLINA ESPITIA JEREZ', 'EDWING FABIÁN ...   22 Noviembre 2022
# 2    ['ANA CAROLINA ESPITIA JEREZ', 'ANGÉLICA LISBE...  26 Septiembre 2022
# 3                               ['MILENE JARAVA DÍAZ']      10 Agosto 2022
# 4    ['INTI RAÚL ASPRILLA REYES', 'MARÍA JOSÉ PIZAR...     20 Octubre 2022
# ..                                                 ...                 ...
# 899  ['ANDREA PADILLA VILLARRAGA', 'HUMBERTO DE LA ...      01 Agosto 2023
# 915  ['OLGA LUCIA VELÁSQUEZ NIETO', 'GLORIA LILIANA...       25 Julio 2023
# 916           ['OLMES DE JESÚS ECHEVERRÍA DE LA ROSA']  06 Septiembre 2023
# 917  ['JHON JAIRO BERRIO LÓPEZ', 'ÓSCAR DARÍO PÉREZ...     28 Febrero 2024
# 918  ['JULIO ELIAS VIDAL', 'ALEJANDRO ALBERTO VEGA ...       20 Julio 2023
#
#     Comision                                             Estado
# 0      SEXTA                 LEY   2414 DEL 8 DE AGOSTO DE 2024
# 1      SEXTA             LEY   2427 DEL 9 DE SEPTIEMBRE DE 2024
# 2      SEXTA                 LEY   2389 DEL 26 DE JULIO DE 2024
# 3    SEPTIMA  ARCHIVADO   Art 190 Ley 5 de 1992 (No se discu...
# 4    SEGUNDA               LEY   2408 DEL 05 DE AGOSTYO DE 2024
# ..       ...                                                ...
# 899   QUINTA  PENDIENTE RENDIR PONENCIA PARA SEGUNDO DEBATE ...
# 915  SEPTIMA  PENDIENTE RENDIR PONENCIA PARA SEGUNDO DEBATE ...
# 916  TERCERA  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
# 917  TERCERA  PENDIENTE DISCUTIR PONENCIA PARA SEGUNDO DEBAT...
# 918  SEPTIMA  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
#
# [181 rows x 8 columns]

# %%
bills_mis_merge = bills_mis.copy().merge(bills_txt_info, on=['number'], how='inner') # Merge again to see if all matches
bills_mis_merge
# Out:
#      number No Senado No Camara  \
# 0  AL012-23    012/23    112/22
# 1  AL011-23    011/23    060/22
#
#                                               Titulo  \
# 0  POR MEDIO DEL CUAL SE ESTABLECEN CONDICIONES Y...
# 1  POR MEDIO DE LA CUAL SE DICTAN DISPOSICIONES P...
#
#                                              Autores Fecha Radicacion  \
# 0  ['ANGÉLICA LISBETH LOZANO CORREA', 'ANDREA PAD...   04 Agosto 2022
# 1  ['JUAN CARLOS GARCÉS ROJAS', 'JOHN MOISES BESA...    26 Julio 2022
#
#   Comision                               Estado  \
# 0   QUINTA  LEY   2404 DEL 02 DE AGOSTO DE 2024
# 1  SEPTIMA   LEY   2397 DEL 31 DE JULIO DE 2024
#
#                                           title  \
# 0  PAL 12-23 Sistema General de Participaciones
# 1                       PAL 11-23 Policía Local
#
#                                                  url         type_bill  \
# 0  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 1  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
#
#         year       period
# 0  2023-2024  2022 - 2026
# 1  2023-2024  2022 - 2026

# %%
bills_merge = bills_merge[~bills_merge['title'].isna()].copy()
bills = pd.concat([bills_merge, bills_mis_merge]).reset_index(drop=True)
bills
# Out:
#     Fecha Radicacion No Senado No Camara  \
# 0       23 Mayo 2023    331/23       NaN
# 1       18 Mayo 2023    330/23    416/23
# 2       09 Mayo 2023    321/23       NaN
# 3       04 Mayo 2023    320/23    415/23
# 4      27 Abril 2023    319/23       NaN
# ..               ...       ...       ...
# 760    20 Julio 2024    003/24       NaN
# 761    20 Julio 2024    002/24       NaN
# 762    20 Julio 2024    001/24       NaN
# 763   04 Agosto 2022    012/23    112/22
# 764    26 Julio 2022    011/23    060/22
#
#                                                 Estado  \
# 0    ARCHIVADO   ARCHIVADO ARTICULO 190 LEY 5 Y ART...
# 1                LEY   Ley 2298 de 2023 gac n 853/2023
# 2    ARCHIVADO   Art 190 ley 5 de 1992 no alcanzo a...
# 3    ARCHIVADO   Art 190 ley 5 de 1992 no se rindió...
# 4    ARCHIVADO   ARCHIVADO ARTICULO 190 LEY 5 Y ART...
# ..                                                 ...
# 760  PENDIENTE DISCUTIR PONENCIA PARA SEGUNDO DEBAT...
# 761  PENDIENTE RENDIR PONENCIA PARA PRIMER DEBATE E...
# 762  PENDIENTE DISCUTIR PONENCIA PARA PRIMER DEBATE...
# 763                LEY   2404 DEL 02 DE AGOSTO DE 2024
# 764                 LEY   2397 DEL 31 DE JULIO DE 2024
#
#                                                 Titulo  \
# 0    POR MEDIO DE LA CUAL SE CREA LA AGENCIA NACION...
# 1    POR LA CUAL SE ESTABLECEN LOS PARÁMETROS PARA ...
# 2    POR MEDIO DEL CUAL SE REGULA LA PRESTACIÓN DE ...
# 3    POR EL CUAL SE MODIFICA EL ARTÍCULO 74 DE LA L...
# 4    POR MEDIO DEL CUAL SE DICTAN MEDIDAS PARA RECO...
# ..                                                 ...
# 760  POR MEDIO DE LA CUAL SE PROHÍBE EL USO DEL GLI...
# 761  POR MEDIO DE LA CUAL SE MODIFICA Y ADICIONA A ...
# 762  POR MEDIO DE LA CUAL SE DICTAN LOS LINEAMIENTO...
# 763  POR MEDIO DEL CUAL SE ESTABLECEN CONDICIONES Y...
# 764  POR MEDIO DE LA CUAL SE DICTAN DISPOSICIONES P...
#
#                                                Autores Comision   Cuatrienio  \
# 0    ['ANA MARÍA CASTAÑEDA GÓMEZ', 'DAVID LUNA SÁNC...  PRIMERA  2022 - 2026
# 1    ['Ministro del Interior', 'Dr. LUIS FERNANDO V...  PRIMERA  2022 - 2026
# 2                    ['ALEX JAVIER FLÓREZ HERNÁNDEZ.']    SEXTA  2022 - 2026
# 3    ['JOSÉ DAVID NAME CARDOZO', 'EDGAR DE JESÚS DÍ...   QUINTA  2022 - 2026
# 4                       ['NADIA GEORGETTE BLEL SCAFF']  PRIMERA  2022 - 2026
# ..                                                 ...      ...          ...
# 760  ['ESMERALDA HERNÁNDEZ SILVA', 'RICHARD HUMBERT...   QUINTA  2022 - 2026
# 761  ['LORENA RIOS CUELLAR', 'JOSUE ALIRIO BARRERA ...  PRIMERA  2022 - 2026
# 762  ['LORENA RIOS CUELLAR', 'SOLEDAD TAMAYO TAMAYO...  SEPTIMA  2022 - 2026
# 763  ['ANGÉLICA LISBETH LOZANO CORREA', 'ANDREA PAD...   QUINTA          NaN
# 764  ['JUAN CARLOS GARCÉS ROJAS', 'JOHN MOISES BESA...  SEPTIMA          NaN
#
#      Legislatura                                              url_x  \
# 0    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 1    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 2    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 3    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# 4    2022 - 2023  https://leyes.senado.gov.co/proyectos/index.ph...
# ..           ...                                                ...
# 760  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 761  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 762  2024 - 2025  https://leyes.senado.gov.co/proyectos/index.ph...
# 763          NaN                                                NaN
# 764          NaN                                                NaN
#
#     Tipo de ley    number                                            title  \
# 0            PL  PL331-22                      PL 331-23 Seguridad Digital
# 1            PL  PL330-22                              PL 330-23 Diputados
# 2            PL  PL321-22                       PL 321-23 Servicios Aereos
# 3            PL  PL320-22  PL 320-23 Servicio Público de EnergiaDescargar
# 4            PL  PL319-22                      PL 319-23 Violencia Vicaria
# ..          ...       ...                                              ...
# 760          PL  PL003-24                              PL 003-24 GLIFOSATO
# 761          PL  PL002-24              PL 002-24 VICTIMAS SECTOR RELIGIOSO
# 762          PL  PL001-24              PL 001-24 CON LOS NIÑOS NO TE METAS
# 763         NaN  AL012-23     PAL 12-23 Sistema General de Participaciones
# 764         NaN  AL011-23                          PAL 11-23 Policía Local
#
#                                                  url_y         type_bill  \
# 0    https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 1    https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 2    https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 3    https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 4    https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# ..                                                 ...               ...
# 760  https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 761  https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 762  https://leyes.senado.gov.co/proyectos/index.ph...   Proyecto de ley
# 763                                                NaN  Acto legislativo
# 764                                                NaN  Acto legislativo
#
#           year       period                                                url
# 0    2022-2023  2022 - 2026                                                NaN
# 1    2022-2023  2022 - 2026                                                NaN
# 2    2022-2023  2022 - 2026                                                NaN
# 3    2022-2023  2022 - 2026                                                NaN
# 4    2022-2023  2022 - 2026                                                NaN
# ..         ...          ...                                                ...
# 760  2024-2025  2022 - 2026                                                NaN
# 761  2024-2025  2022 - 2026                                                NaN
# 762  2024-2025  2022 - 2026                                                NaN
# 763  2023-2024  2022 - 2026  https://leyes.senado.gov.co/proyectos/index.ph...
# 764  2023-2024  2022 - 2026  https://leyes.senado.gov.co/proyectos/index.ph...
#
# [765 rows x 18 columns]

# %% [markdown]
# Finding the missing projects

# %%
bills_txt_mis = bills_txt_info[~bills_txt_info['number'].isin(bills['number'])]
bills_txt_mis['year'].value_counts()
# Out:
# year
# 2022-2023    42
# 2024-2025    17
# 2023-2024    17
# Name: count, dtype: int64

# %%
bills_house.loc[:, 'No Senado'] = bills_house['No Senado'].fillna('')
bills_house['number'] = bills_house.apply(lambda row: get_bill_number(row['No Senado'], row['Legislatura'], row['Tipo de ley']), axis=1)
bills_house['number'].value_counts(dropna=False)
# Out:
# number
#             710
# PL280-22      2
# PL069-23      2
# PL329-22      2
# PL335-22      2
#            ...
# PL193-23      1
# AL008-23      1
# PL275-23      1
# PL083-23      1
# AL033-22      1
# Name: count, Length: 148, dtype: int64

# %%
bills_merge_house = bills_house[bills_house['number']!=''].merge(bills_txt_mis, on=['number'], how='inner')
bills_merge_house = bills_merge_house.rename({'Autor':'Autores', 'Título':'Titulo'})
bills_merge_house
# Out:
#     No Cámara                         No Senado  \
# 0   437/2024C                         018/2024S
# 1   436/2024C                         020/2024S
# 2   290/2023C                         004/2023C
# 3   280/2023C     008/2023S acumulado 003/2023S
# 4   298/2022C                         014/2022S
# 5   293/2022C                         022/2022S
# 6   269/2022C                         001/2022S
# 7   268/2022C                         012/2022S
# 8   267/2022C                         010/2022S
# 9   260/2022C  002/2022S acum. 03/22S y 011/22S
# 10  254/2022C                         019/2022S
# 11  243/2022C                         018/2022S
# 12  214/2022C                         039/2022S
# 13  185/2022C                         036/2022S
# 14  173/2022C                         035/2022S
# 15  156/2022C                         040/2022S
# 16  120/2022C                         038/2022S
# 17  117/2022C                         037/2022S
# 18  002/2022C                         033/2022S
#
#                                       Nombre proyecto       Tipo de ley  \
# 0     AUTONOMÍA DEPARTAMENTOS, DISTRITOS Y MUNICIPIOS  Acto Legislativo
# 1                           DERECHO A LA ALIMENTACIÓN  Acto Legislativo
# 2                           DERECHO A LA ALIMENTACIÓN  Acto Legislativo
# 3                                      MESADA CATORCE  Acto Legislativo
# 4                                      ACCESO AL AGUA  Acto Legislativo
# 5                        CIRCUNSCRIPCIÓN DISCAPACIDAD  Acto Legislativo
# 6                           DERECHO A LA ALIMENTACIÓN  Acto Legislativo
# 7                                    SERVICIO MILITAR  Acto Legislativo
# 8   REDUCCION MIEMBROS DEL CONGRESO Y REDUCCION SA...  Acto Legislativo
# 9                    MODIFICACIÓN PERIODO LEGISLATIVO  Acto Legislativo
# 10     CAMPESINADO COMO SUJETO DE ESPECIAL PROTECCIÓN  Acto Legislativo
# 11                                   REFORMA POLITICA  Acto Legislativo
# 12                             FORMATO DE COMUNICADOS  Acto Legislativo
# 13            MANIZALES DISTRITO EJE DEL CONOCIMIENTO  Acto Legislativo
# 14                               JURISDICCIÓN AGRARIA  Acto Legislativo
# 15                                 SENADOS REGIONALES  Acto Legislativo
# 16                      SUPERINTENDENCIA DE EDUCACIÓN  Acto Legislativo
# 17                 SISTEMA GENERAL DE PARTICIPACIONES  Acto Legislativo
# 18                                           CANNABIS  Acto Legislativo
#
#                                               Autores               Estado  \
# 0   ['Iván Leonidas Name Vásquez', ' Guido Echever...  Trámite en Plenaria
# 1   ['Eduard Giovanny Sarmiento HidalgoAlfredo Raf...  Trámite en Plenaria
# 2   ['Alexander Guarín Silva', ' José Eliécer Sala...            Archivado
# 3   ['Ministro de Defensa Nacional - Ivan Velasque...  Trámite en Plenaria
# 4   ['Julia Miranda Londoño', ' Elkin Rodolfo Ospi...            Archivado
# 5   ['Dolcey Oscar Torres Romero', ' Silvio José C...            Archivado
# 6   ['Y OTRAS FIRMAS  Julián David López Tenorio',...                 Otro
# 7   ['Daniel Carvalho Mejía', ' Jaime Raúl Salaman...            Archivado
# 8   ['Hernán Darío Cadavid Márquez', ' Olmes de Je...            Archivado
# 9   ['H.S. Oscar Barreto Quiroga Marcos Daniel Pin...     Acto Legislativo
# 10  ['Ministra de Agricultura - Cecilia Lopez Mont...     Acto Legislativo
# 11  ['Alirio Uribe MuñozRoy Leonardo Barreras Mont...                 Otro
# 12  ['Jorge Alejandro Ocampo Giraldo', ' Eduard Gi...            Archivado
# 13  ['Juan Sebastián Gómez Gonzáles', ' Wilder Ibe...            Archivado
# 14  ['Ministro del Interior - Alfonso Prada Gil', ...     Acto Legislativo
# 15  ['Jorge Méndez Hernández', ' Carlos Alberto Cu...            Archivado
# 16  ['Jorge Eliécer Tamayo Marulanda', ' Teresa De...            Archivado
# 17  ['Olga Lucia Velásquez Nieto', ' Elkin Rodolfo...            Archivado
# 18  ['Juan Carlos Lozada Vargas', ' Julián David L...            Archivado
#
#                                       Comisión  Origen  Legislatura  \
# 0   Comisión Primera Constitucional Permanente  Senado  2023 - 2024
# 1   Comisión Primera Constitucional Permanente  Senado  2023 - 2024
# 2   Comisión Primera Constitucional Permanente  Senado  2023 - 2024
# 3   Comisión Primera Constitucional Permanente  Senado  2023 - 2024
# 4   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 5   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 6   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 7   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 8   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 9   Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 10  Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 11  Comisión Primera Constitucional Permanente  Senado  2022 - 2023
# 12  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 13  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 14  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 15  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 16  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 17  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
# 18  Comisión Primera Constitucional Permanente  Cámara  2022 - 2023
#
#                                                Título  ...  \
# 0   POR EL CUAL SE FORTALECE LA AUTONOMÍA DE LOS D...  ...
# 1   POR EL CUAL SE MODIFICA EL ARTÍCULO 65 DE LA C...  ...
# 2   POR EL CUAL SE MODIFICA EL ARTÍCULO 65 DE LA C...  ...
# 3   POR MEDIO DEL CUAL SE MODIFICA EL ARTÍCULO 48 ...  ...
# 4   Por el cual se incluye el artículo 11 A dentro...  ...
# 5   POR EL CUAL SE PROMUEVE LA PARTICIPACIÓN POLÍT...  ...
# 6   POR EL CUAL SE MODIFICA EL ARTICULO 65 DE LA C...  ...
# 7   Por medio del cual se elimina el servicio mili...  ...
# 8   POR MEDIO DEL CUAL SE REDUCE EL NUMERO DE MIEM...  ...
# 9   POR MEDIO DE LA CUAL SE MODIFICA EL ARTICULO 1...  ...
# 10  POR MEDIO DEL CUAL SE RECONOCE AL CAMPESINADO ...  ...
# 11  POR MEDIO DEL CUAL SE ADOPTA UNA REFORMA POLITICA  ...
# 12  POR MEDIO DEL CUAL SE INTERPRETA EL PARÁGRAFO ...  ...
# 13  Por el cual se otorga al municipio de Manizale...  ...
# 14  POR EL CUAL SE REFORMA LA CONSTITUCIO N POLI T...  ...
# 15  Por medio del cual se modifican los artículos ...  ...
# 16  Por medio del cual se modifican los artículos ...  ...
# 17  Por medio del cual se modifican los artículos ...  ...
# 18  Por medio del cual se modifica el artículo 49 ...  ...
#
#                                         Observaciones Fecha radicación Cámara  \
# 0   Primer debate cámara Primera PONENTES Coordina...              2024 05 08
# 1   Primer debate cámara Primera PONENTES Coordina...              2024 05 08
# 2   ARCHIVADO ART 224 Y 225 LEY 5tA DE 1992 Primer...              2023 10 26
# 3   TRAMITE PLENARIA SEGUNDA VUELTA Primer debate ...              2023 10 11
# 4   ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 11 23
# 5   ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 11 23
# 6   PENDIENTE PUBLICACION PRIMERA VUELTA Primer de...              2022 11 02
# 7   ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 11 02
# 8   ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 11 02
# 9   Acto Legislativo 02 del 6 de julio de 2023 Pri...              2022 10 27
# 10  ACTO LEGISLATIVO 01 DEL 05 DE JULIO DE 2023 Pr...              2022 10 25
# 11  PENDIENTE PUBLICACION PRIMERA VUELTA DIARIO OF...              2022 10 19
# 12  Carta de Retiro de Autoria del Proyecto de Ley...              2022 09 28
# 13  ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 09 07
# 14  Diario Oficial 1ra vuelta No 52 297 Acto Legis...              2022 08 31
# 15  Acumulado con el Proyecto de Acto Legislativo ...              2022 08 24
# 16  Adhesion de los H R Jairo Humberto Cristo Luis...              2022 08 09
# 17  ARCHIVADO ART 224 Y 225 LEY 5ta DE 1992 Primer...              2022 08 05
# 18  Diario Oficial 1ra vuelta No 52 275 ARCHIVADO ...              2022 07 21
#
#    Fecha radicación Senado                                              url_x  \
# 0               2024 02 16  https://www.camara.gov.co/autonomia-departamen...
# 1               2024 02 16  https://www.camara.gov.co/derecho-a-la-aliment...
# 2               2023 07 25  https://www.camara.gov.co/derecho-a-la-aliment...
# 3               2023 08 08           https://www.camara.gov.co/mesada-catorce
# 4               2022 08 04           https://www.camara.gov.co/acceso-al-agua
# 5               2022 08 30  https://www.camara.gov.co/circunscripcion-disc...
# 6               2022 07 20  https://www.camara.gov.co/derecho-a-la-aliment...
# 7               2022 08 01       https://www.camara.gov.co/servicio-militar-1
# 8               2022 07 29  https://www.camara.gov.co/reduccion-miembros-d...
# 9               2022 07 21  https://www.camara.gov.co/modificacion-periodo...
# 10              2022 08 17  https://www.camara.gov.co/campesinado-como-suj...
# 11              2022 08 11       https://www.camara.gov.co/reforma-politica-0
# 12                     NaN   https://www.camara.gov.co/formato-de-comunicados
# 13                     NaN  https://www.camara.gov.co/manizales-distrito-e...
# 14                     NaN     https://www.camara.gov.co/jurisdiccion-agraria
# 15                     NaN       https://www.camara.gov.co/senados-regionales
# 16                     NaN  https://www.camara.gov.co/superintendencia-de-...
# 17                     NaN  https://www.camara.gov.co/sistema-general-de-p...
# 18                     NaN               https://www.camara.gov.co/cannabis-1
#
#       number                                              title  \
# 0   AL018-23               PAL 18-24 Autonomia de Departamentos
# 1   AL020-23                     PAL 20-24 Derecho Alimentación
# 2   AL004-23                             PAL 04-23 Alimentación
# 3   AL008-23                                PAL 08-23 Mesada 14
# 4   AL014-22                          PAL 14-22 Derecho al Agua
# 5   AL022-22  PAL 22-22 Crea circunscripcion especial a pers...
# 6   AL001-22             PAL 01-22 Modifica Art 65 Constitución
# 7   AL012-22                         PAL 12-22 Servicio Militar
# 8   AL010-22  PAL 10-22 Reduccion miembros del congreso y re...
# 9   AL002-22       PAL 02-22 Modifica Art 138 Constitución 1991
# 10  AL019-22               PAL 19-22 Derechos de los campesinos
# 11  AL018-22               PAL 18-22 Financiamiento de campañas
# 12  AL039-22                   PAL 39-22 Formato de Comunicados
# 13  AL036-22     PAL 36-22 Distrito especial manizales (Caldas)
# 14  AL035-22                     PAL 35-22 Jurisdicción Agraria
# 15  AL040-22                       PAL 40-22 Senados Regionales
# 16  AL038-22            PAL 38-22 Superintendencia de Educacion
# 17  AL037-22  PAL 37-22 MODIFICAN LOS ARTÍCULOS 356 Y 357 DE...
# 18  AL033-22                   PAL 33-22 Cannabis de uso Adulto
#
#                                                 url_y         type_bill  \
# 0   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 1   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 2   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 3   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 4   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 5   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 6   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 7   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 8   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 9   https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 10  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 11  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 12  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 13  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 14  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 15  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 16  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 17  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
# 18  https://leyes.senado.gov.co/proyectos/index.ph...  Acto legislativo
#
#          year       period
# 0   2023-2024  2022 - 2026
# 1   2023-2024  2022 - 2026
# 2   2023-2024  2022 - 2026
# 3   2023-2024  2022 - 2026
# 4   2022-2023  2022 - 2026
# 5   2022-2023  2022 - 2026
# 6   2022-2023  2022 - 2026
# 7   2022-2023  2022 - 2026
# 8   2022-2023  2022 - 2026
# 9   2022-2023  2022 - 2026
# 10  2022-2023  2022 - 2026
# 11  2022-2023  2022 - 2026
# 12  2022-2023  2022 - 2026
# 13  2022-2023  2022 - 2026
# 14  2022-2023  2022 - 2026
# 15  2022-2023  2022 - 2026
# 16  2022-2023  2022 - 2026
# 17  2022-2023  2022 - 2026
# 18  2022-2023  2022 - 2026
#
# [19 rows x 26 columns]

# %% [markdown]
# Concat data

# %%
columns = ['number', 'title', 'Autores', 'type_bill', 'year', 'period', 'state_bill']
bills = pd.concat([bills_merge, bills_mis_merge, bills_merge_house]).reset_index(drop=True)
bills['state_bill'] = bills['Estado'].str.lower().str.split().str[0]
bills = bills[columns].copy()
bills
# Out:
#        number                                              title  \
# 0    PL331-22                        PL 331-23 Seguridad Digital
# 1    PL330-22                                PL 330-23 Diputados
# 2    PL321-22                         PL 321-23 Servicios Aereos
# 3    PL320-22    PL 320-23 Servicio Público de EnergiaDescargar
# 4    PL319-22                        PL 319-23 Violencia Vicaria
# ..        ...                                                ...
# 779  AL035-22                     PAL 35-22 Jurisdicción Agraria
# 780  AL040-22                       PAL 40-22 Senados Regionales
# 781  AL038-22            PAL 38-22 Superintendencia de Educacion
# 782  AL037-22  PAL 37-22 MODIFICAN LOS ARTÍCULOS 356 Y 357 DE...
# 783  AL033-22                   PAL 33-22 Cannabis de uso Adulto
#
#                                                Autores         type_bill  \
# 0    ['ANA MARÍA CASTAÑEDA GÓMEZ', 'DAVID LUNA SÁNC...   Proyecto de ley
# 1    ['Ministro del Interior', 'Dr. LUIS FERNANDO V...   Proyecto de ley
# 2                    ['ALEX JAVIER FLÓREZ HERNÁNDEZ.']   Proyecto de ley
# 3    ['JOSÉ DAVID NAME CARDOZO', 'EDGAR DE JESÚS DÍ...   Proyecto de ley
# 4                       ['NADIA GEORGETTE BLEL SCAFF']   Proyecto de ley
# ..                                                 ...               ...
# 779  ['Ministro del Interior - Alfonso Prada Gil', ...  Acto legislativo
# 780  ['Jorge Méndez Hernández', ' Carlos Alberto Cu...  Acto legislativo
# 781  ['Jorge Eliécer Tamayo Marulanda', ' Teresa De...  Acto legislativo
# 782  ['Olga Lucia Velásquez Nieto', ' Elkin Rodolfo...  Acto legislativo
# 783  ['Juan Carlos Lozada Vargas', ' Julián David L...  Acto legislativo
#
#           year       period state_bill
# 0    2022-2023  2022 - 2026  archivado
# 1    2022-2023  2022 - 2026        ley
# 2    2022-2023  2022 - 2026  archivado
# 3    2022-2023  2022 - 2026  archivado
# 4    2022-2023  2022 - 2026  archivado
# ..         ...          ...        ...
# 779  2022-2023  2022 - 2026       acto
# 780  2022-2023  2022 - 2026  archivado
# 781  2022-2023  2022 - 2026  archivado
# 782  2022-2023  2022 - 2026  archivado
# 783  2022-2023  2022 - 2026  archivado
#
# [784 rows x 7 columns]

# %%
bills.describe()
# Out:
#           number                        title                Autores  \
# count        784                          784                    784
# unique       784                          784                    645
# top     PL331-22  PL 331-23 Seguridad Digital  ['FABIAN DIAZ PLATA']
# freq           1                            1                     19
#
#               type_bill       year       period state_bill
# count               784        784          784        784
# unique                2          3            1         10
# top     Proyecto de ley  2022-2023  2022 - 2026  archivado
# freq                763        327          784        359

# %% [markdown]
# ## Congresspeople

# %%
congress_info = pd.read_csv(raw_path + 'Congresistas 2022 - 2026.csv')
congress_info
# Out:
#                nombres          apellidos  \
# 0        Yenica Sugein     Acosta Infante
# 1      Modesto Enrique     Aguilera Vides
# 2        Ingrid Johana    Aguirre Juvinao
# 3         Luis Alberto       Albán Urbano
# 4       Martha Lisbeth     Alfonso Jurado
# ..                 ...                ...
# 306  Alejandro Alberto         Vega Pérez
# 307     Manuel Antonio  Virgüez Piraquive
# 308  Antonio Luis Toño   Zabaraín Guevara
# 309        Bérner León     Zambrano Eraso
# 310    Isabel Cristina       Zuleta Lopez
#
#                                               partido  \
# 0                                  Centro Democrático
# 1                                      Cambio Radical
# 2                                    Fuerza Ciudadana
# 3                                             Comunes
# 4                           Pacto Histórico Coalición
# ..                                                ...
# 306                                Liberal Colombiano
# 307                        MIRA Colombia Justa Libres
# 308                                    Cambio Radical
# 309  Partido de la U Partido de la Unión por la Gente
# 310                         Pacto Histórico Coalición
#
#                                               comision  \
# 0                            Legal de Derechos Humanos
# 1        Especial de Vigilancia al Organismo Electoral
# 2                                         Sin comisión
# 3                                    Primera de Cámara
# 4                                         Sin comisión
# ..                                                 ...
# 306  Especial de Vigilancia a ordenamiento territorial
# 307                                  Segunda de Senado
# 308      Especial de Vigilancia al Organismo Electoral
# 309                   Asesora de Relaciones Exteriores
# 310                                       Sin comisión
#
#                   corporacion  \
# 0    Cámara de Representantes
# 1    Cámara de Representantes
# 2    Cámara de Representantes
# 3    Cámara de Representantes
# 4    Cámara de Representantes
# ..                        ...
# 306                    Senado
# 307                    Senado
# 308                    Senado
# 309                    Senado
# 310                    Senado
#
#                                        Circunscripción      Grado de estudio  \
# 0    Circunscripción Territorial de Amazonas en Ama...       Especialización
# 1    Circunscripción Territorial de Atlántico en At...              Maestría
# 2    Circunscripción Territorial de Magdalena en Ma...       Especialización
# 3    Circunscripción Territorial de Valle del Cauca...         Universitaria
# 4      Circunscripción Territorial de Tolima en Tolima       Especialización
# ..                                                 ...                   ...
# 306                   Circunscripción Nacional en Meta       Especialización
# 307       Circunscripción Nacional en Distrito Capital       Especialización
# 308              Circunscripción Nacional en Magdalena  Sin grado de estudio
# 309                 Circunscripción Nacional en Nariño       Especialización
# 310              Circunscripción Nacional en Antioquia         Universitaria
#
#                        Profesión Cuatrienio Fecha de nacimiento  ...  \
# 0           Ciencias de la Salud  2022 2026    February 11 1980  ...
# 1                      Abogado a  2022 2026    February 12 1959  ...
# 2    Administrador a de empresas  2022 2026         May 12 1980  ...
# 3                        Docente  2022 2026      August 16 1957  ...
# 4                        Docente  2022 2026        July 22 2022  ...
# ..                           ...        ...                 ...  ...
# 306                    Abogado a  2022 2026    February 11 1986  ...
# 307                    Abogado a  2022 2026         May 10 1969  ...
# 308                   Empresario  2022 2026    December 31 1962  ...
# 309                   Economista  2022 2026      August 15 1958  ...
# 310                  Sociólogo a  2022 2026       April 12 1982  ...
#
#     Lugar de nacimiento     Género      Whatsapp  \
# 0               Leticia   Femenino    3214181533
# 1          Barranquilla  Masculino           NaN
# 2               Ciénaga   Femenino           NaN
# 3                  Cali  Masculino           NaN
# 4                Líbano   Femenino           NaN
# ..                  ...        ...           ...
# 306       Villavicencio  Masculino           NaN
# 307              Bogotá  Masculino           NaN
# 308             Ciénaga  Masculino           NaN
# 309           Taminango  Masculino  300 213 8489
# 310             Ituango   Femenino           NaN
#
#                                                YouTube  \
# 0                                                  NaN
# 1                                 https bit ly 3sYRzcR
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 306  https www youtube com channel UCkAfRnlqr8b4epu...
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
#                                Oficina             Teléfono Oficina  \
# 0           405B Ed Nuevo del Congreso   4325100 ext 4311 4312 4314
# 1        427 428 Ed Nuevo del Congreso   4325100 ext 3812 3813 3814
# 2                                  NaN                          NaN
# 3    Capitolio Nacional Salón Amarillo             4325100 ext 3830
# 4                                  NaN                          NaN
# ..                                 ...                          ...
# 306         236B Ed Nuevo del Congreso        4325100 ext 3294 3295
# 307          617 618 Ed Nuevo Congreso  382 3000 ext 3609 3610 3726
# 308              412 Ed Nuevo Congreso       382 3000 ext 3438 3439
# 309             622B Ed Nuevo Congreso       382 3000 ext 3623 3624
# 310                                NaN                          NaN
#
#                  Correo Electrónico veces congresista  \
# 0       yenica acosta camara gov co                 2
# 1    modesto aguilera camara gov co                 3
# 2                               NaN                 1
# 3          luis alban camara gov co                 3
# 4                               NaN                 1
# ..                              ...               ...
# 306                             NaN                 2
# 307       manuelvirguez webmira com                 2
# 308                             NaN                 2
# 309                             NaN                10
# 310                             NaN                 1
#
#      total experiencias públicas  experiencias mismo partido
# 0                              2                           2
# 1                              3                           3
# 2                              1                           1
# 3                              3                           2
# 4                              1                           1
# ..                           ...                         ...
# 306                            2                           2
# 307                            4                           0
# 308                            2                           2
# 309                           15                           0
# 310                            1                           1
#
# [311 rows x 21 columns]

# %%
def get_party_positions(party_name):
    party_positions = {
        'pacto hist': 1,
        'liberal ': 0,  # Originally 1, but changed it in 2023
        'conservador': 0,  # Originally 1, but changed it in 2023
        'cambio radical': -1,  # Originally 0, but changed it in 2023
        'centro democratico': -1,
        'partido de la u ': 0,  # Originally 1, but changed it in 2023
        'verde': 1,
        'comunes': 1,
        'mira': 0,
        'justa libres': -1,
        'liga': -1,
        'mais': 1,
        'polo': 1,
        'nuevo liberalismo': 0,
        'aico': 1,
        'colombia renaciente': 1,
        'fuerza ciudadana': 1,
        'gente en movimiento': 1,
        'juntos por caldas': 0, # Union of Nuevo Liberalismo and MIRA
    }
    pps = []  # Saved in an array the position for coalitions
    for pp in party_positions:
        if pp in party_name.lower().replace('á', 'a'):
            pps.append(party_positions[pp])
    if len(pps) > 0:
        return np.mean(pps)
    # The ones that do not have a text is because they are reserved seats for victims of the conflict and indigenous and black communities.
    # They are not necessary parties, but behave as being in favor of the government
    return 1  

congress_info['party_position'] = congress_info.apply(lambda row: get_party_positions(row['partido']), axis=1)
congress_info['party_position'].value_counts()
# Out:
# party_position
#  1.0    120
#  0.0    117
# -1.0     65
# -0.5      9
# Name: count, dtype: int64

# %%
# Changing the -0.5 of the coalition of a independent with an opposition to make it opposition
congress_info.loc[congress_info['party_position']==-0.5, 'party_position'] = -1
congress_info['party_position'].value_counts()
# Out:
# party_position
#  1.0    120
#  0.0    117
# -1.0     74
# Name: count, dtype: int64

# %%
# Match authors with their first last name
congress_info['apellidos'].value_counts(dropna=False) # It is a unique identifier of the data
# Out:
# apellidos
# Acosta Infante      1
# Bedoya Pérez        1
# Blanco Álvarez      1
# Bitar Castilla      1
# Besaile Fayad       1
#                    ..
# Miranda Londoño     1
# Méndez Hernández    1
# Martínez Sánchez    1
# Manzur Imbett       1
# Zuleta Lopez        1
# Name: count, Length: 311, dtype: int64

# %% [markdown]
# ## Getting the authors' positions

# %%
congress_info['last_names'] = congress_info.apply(lambda row: re.sub(r'[^a-z\s]', '', unidecode(row['apellidos'].lower())).strip(), axis=1)
congress_info['first_names'] = congress_info.apply(lambda row: re.sub(r'[^a-z\s]', '', unidecode(row['nombres'].lower())).strip(), axis=1)
congress_info['full_name'] = congress_info.apply(lambda row: re.sub(r'[^a-z\s]', '', unidecode(row['nombres'].lower())).strip() + ' ' +
                                                 re.sub(r'[^a-z\s]', '', unidecode(row['apellidos'].lower())).strip(), axis=1)
def get_authors_position(authors, congress):
    position = 0
    count = 0
    authors = ast.literal_eval(authors.replace(';', "', '").replace(':', "', '").replace('.', "', '").replace(' y ', "', '").replace(r'\n', "', '"))
    for author in authors:
        # Lower case and removing accents to ensure merging 
        author = re.sub(r'[^a-z\s]', '', unidecode(author.lower())).strip()
        author = author.replace('honorables', '')\
                  .replace('senadores', '')\
                  .replace('representantes', '')\
                  .replace('honorable', '')\
                  .replace('senador', '')\
                  .replace('representante', '')\
                  .replace('otra', '')\
                  .replace('firma', '')\
                  .replace('legible', '')\
                  .replace('  ', ' ')\
                  .strip()
        author_lastnames = ' '.join(author.split(' ')[-2:])
        
       #  print('->', author)
        if 'ministr' not in author and 'presidente' not in author and 'direc' not in author and 'contralor' not in author and len(author)>8:

            # Check if last_name is in the list 
            if author_lastnames in congress['last_names'].values:
                position += congress[congress['last_names']==author_lastnames]['party_position'].values[0]
                count += 1
            else: 
                closest_name = process.extractOne(author, congress['full_name'], scorer=fuzz.partial_ratio)
                if closest_name[1] >= 75:  # Add only the highest matches
                    position += congress[congress['full_name']==closest_name[0]]['party_position'].values[0]
                    count += 1
                # else:
                    # print('->', author, closest_name[0], closest_name[1])
    return [position/count if count > 0 else 0, count]

# %%
# Dropping the bills that have 0 authors, which means that nonw of their authors were congresspeople
temp_df = bills.apply(
    lambda row: get_authors_position(row['Autores'], congress_info), 
    axis=1, 
    result_type='expand'
)
temp_df.columns = ['authors_positions', 'authors_count']
temp_df
# Out:
#      authors_positions  authors_count
# 0            -0.666667            3.0
# 1             0.000000            0.0
# 2             1.000000            1.0
# 3             0.500000            8.0
# 4             0.000000            1.0
# ..                 ...            ...
# 779           0.812500           32.0
# 780          -0.705882           17.0
# 781          -0.083333           24.0
# 782           0.882353           17.0
# 783           0.625000           32.0
#
# [784 rows x 2 columns]

# %%
bills['authors_positions'] = temp_df['authors_positions'].copy()
bills['authors_count'] = temp_df['authors_count'].copy()
bills.describe()
# Out:
#        authors_positions  authors_count
# count         784.000000     784.000000
# mean            0.194397       9.006378
# std             0.688562      12.147821
# min            -1.000000       0.000000
# 25%            -0.108135       1.000000
# 50%             0.000000       4.000000
# 75%             1.000000      13.000000
# max             1.000000     114.000000

# %% [markdown]
# Deleting the bills with no identifyable author authors_count==0

# %%
bills = bills[bills['authors_count'] > 0].copy()
bills.describe()
# Out:
#        authors_positions  authors_count
# count         742.000000     742.000000
# mean            0.205401       9.516173
# std             0.706206      12.291297
# min            -1.000000       1.000000
# 25%            -0.142857       1.000000
# 50%             0.045549       4.000000
# 75%             1.000000      14.000000
# max             1.000000     114.000000

# %% [markdown]
# ## Graphs

# %%
# Number of congresspeople in each of the parties and party positions
# Distribution of the number of authors of the bills
# Distribution of the bills according to their authors’ party positions

# %%
from textwrap import wrap

# Count members by party
party_counts = congress_info['partido'].value_counts()

# Get positions for each party
party_positions = congress_info.groupby('partido')['party_position'].first()

# Create a mask for parties with only 1 member
small_parties = party_counts[party_counts <= 2].index

# Create a new DataFrame with grouped small parties
df_grouped = congress_info.copy()
for position in [-1, 0, 1]:
    # Find small parties with this position
    small_parties_pos = [party for party in small_parties 
                        if party_positions[party] == position]
    
    if len(small_parties_pos) > 1:  # Only group if there are multiple small parties
        # Create the new group name
        new_name = f'Others {["Opposition", "Independent", "Pro-Government"][position + 1]}*'
        # Replace party names
        df_grouped.loc[df_grouped['partido'].isin(small_parties_pos), 'partido'] = new_name

# Recalculate counts and positions with grouped parties
party_counts_grouped = df_grouped['partido'].value_counts()
party_positions_grouped = df_grouped.groupby('partido')['party_position'].first()

# Create color map
def get_position_color(pos):
    if pos == -1:
        return '#FF6B6B'  # opposition
    elif pos == 0:
        return '#DEB841'  # independent
    else:
        return '#45B7D1'  # pro-government


colors = [get_position_color(party_positions_grouped[party]) for party in party_counts_grouped.index]
wrapped_labels = ['\n'.join(wrap(label, width=25)) for label in party_counts_grouped.index]

# Create the bar char
fig, ax = plt.subplots(figsize=(10, max(6, len(party_counts_grouped) * 0.5)))  
bars = ax.barh(range(len(party_counts_grouped)), party_counts_grouped.values, color=colors)

for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2,
             f' {int(width)}',
             ha='left', va='center')

# Customize the chart
plt.title('Joint Independents and Opposition have more Congress members than the Pro-Government', pad=20)
plt.ylabel('Political Parties')
plt.xlabel('Number of Congress Members')

ax.set_yticks(range(len(party_counts_grouped)))
ax.set_yticklabels(wrapped_labels, fontsize=9) 

# Add legend
legend_elements = [plt.Rectangle((0,0),1,1, facecolor=get_position_color(pos), 
                               label=label)
                  for pos, label in zip([-1, 0, 1], 
                                      ['Opposition (74)', 'Independent (117)', 'Pro-Government (120)'])]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()

plt.figtext(0.05, 0, '* The Other catgeory was created with the parties or politcal movements in Congress with less than 3 members and grouped by position.', ha='left', fontsize=8)

# Show the plot
plt.savefig('party_positions.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
    
# Calculate histogram data
counts, bins, _ = ax.hist(bills['authors_count'], bins=110, alpha=0.7, 
                             color='#055864', edgecolor='none',
                             label='Number of Bills')
    
    # Customize the plot
plt.title('Most of the bills have more than one author\n 50% have more than 4', pad=20)
ax.set_xlabel('Number of Authors')
ax.set_ylabel('Count of Bills')
    
    # Add grid
ax.grid(True, linestyle='-', alpha=0.7)
ax.set_xticks(list(range(2, 40, 2))) 

plt.axvline(x = bills['authors_count'].median(), color = '#deb841')
plt.text(bills['authors_count'].median(), 2, 'Median', rotation=90, color = '#deb841', fontsize=12)
plt.axvline(x = bills['authors_count'].mean(), color = '#deb841', label = 'Mean')
plt.text(bills['authors_count'].mean(), 2, 'Mean', rotation=90, color = '#deb841', fontsize=12)
plt.axvline(x = bills['authors_count'].quantile(0.75), color = '#deb841')
plt.text(bills['authors_count'].quantile(0.75), 2, 'p75', rotation=90, color = '#deb841', fontsize=12)
    
    
    # Add summary statistics as text
stats_text = f"Mean: {bills['authors_count'].mean():.1f}\n\n"

stats_text += f"Min: {bills['authors_count'].min():.0f}\n"
stats_text += f"P25: {bills['authors_count'].quantile(0.25):.0f}\n"
stats_text += f"Med: {bills['authors_count'].median():.0f}\n"
stats_text += f"P75: {bills['authors_count'].quantile(0.75):.0f}\n"
stats_text += f"Max: {bills['authors_count'].max():.0f}\n\n"

stats_text += f"Bills with one author: {bills[bills['authors_count']==1]['authors_count'].count():.0f}\n"
stats_text += f"Total number of bills: {bills['authors_count'].count():.0f}"
    
    # Add text box with statistics
plt.text(0.55, 0.75, stats_text,
        transform=ax.transAxes,
        verticalalignment='top',
        horizontalalignment='left',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    # Adjust layout
plt.tight_layout()
plt.xlim((2,40))
plt.ylim((0,50))

# Show the plot
plt.savefig('bills_authors.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
    
# Calculate histogram data
counts, bins, _ = ax.hist(bills['authors_positions'], bins=20, alpha=0.7, 
                             color='#59344F', edgecolor='none',
                             label='Number of Bills')
    
    # Customize the plot
plt.title('Half of the bills have authors with an average position of independence or opposition\n There is a large cluster of bills with only Pro-Government sponsors', pad=20)
ax.set_xlabel('Average Position of the Authors')
ax.set_ylabel('Count of Bills')
    
    # Add grid
ax.grid(True, linestyle='-', alpha=0.7)

plt.axvline(x = bills['authors_positions'].median(), color = '#deb841')
plt.text(bills['authors_positions'].median(), 5, 'Median', rotation=90, color = '#deb841', fontsize=12)
plt.axvline(x = bills['authors_positions'].mean(), color = '#deb841')
plt.text(bills['authors_positions'].mean(), 5, 'Mean', rotation=90, color = '#deb841', fontsize=12)
plt.axvline(x = bills['authors_positions'].quantile(0.25), color = '#deb841')
plt.text(bills['authors_positions'].quantile(0.25), 5, 'p25', rotation=90, color = '#deb841', fontsize=12)
plt.axvline(x = bills['authors_positions'].quantile(0.75), color = '#deb841')
plt.text(bills['authors_positions'].quantile(0.75), 5, 'p75', rotation=90, color = '#deb841', fontsize=12)
    
    
    # Add summary statistics as text
stats_text = f"Mean: {bills['authors_positions'].mean():.2f}\n\n"

stats_text += f"Min: {bills['authors_positions'].min():.2f}\n"
stats_text += f"P25: {bills['authors_positions'].quantile(0.25):.2f}\n"
stats_text += f"Med: {bills['authors_positions'].median():.2f}\n"
stats_text += f"P75: {bills['authors_positions'].quantile(0.75):.2f}\n"
stats_text += f"Max: {bills['authors_positions'].max():.2f}"

    
    # Add text box with statistics
plt.text(0.15, 0.75, stats_text,
        transform=ax.transAxes,
        verticalalignment='top',
        horizontalalignment='left',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    # Adjust layout
plt.tight_layout()

# Show the plot
plt.savefig('bills_positions.png')
plt.show()

# %%
bills.to_csv('./Clean/bills.csv')
